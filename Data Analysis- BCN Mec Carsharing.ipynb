# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
df1= pd.read_excel('RESERVES MEC UOC.xlsx')
df1.head()
# Out:
#                       Número de reserva Número de reserva corto  \
# 0  9f866cac-5ad1-4851-89c7-ff079d915943                9F866CAC
# 1  410761c2-3272-473c-b0ec-8154c5aac592                410761C2
# 2  54f2d835-cffd-45f5-be77-df522c50e45a                54F2D835
# 3  1deaef00-b2f4-4684-b96a-33cd715df031                1DEAEF00
# 4  011531a7-267f-4a7f-b79c-a98b810682a0                011531A7
#
#   Fecha de creación de la reserva (UTC) Empresa usuaria Estado civil  \
# 0                   2022-03-21 18:51:00  MEC CARSHARING          NaN
# 1                   2022-03-21 17:58:00  MEC CARSHARING          NaN
# 2                   2022-03-16 07:40:00  MEC CARSHARING          NaN
# 3                   2022-03-21 16:06:00  MEC CARSHARING           MR
# 4                   2022-03-21 16:39:00  MEC CARSHARING          NaN
#
#   Matrícula   Marca   Modelo Categoría                       Cliente  ...  \
# 0  0934 LFF  Nissan  Leaf 40       4.0  COMPARTIM TURISME SOSTENIBLE  ...
# ...

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17649 entries, 0 to 17648
# Data columns (total 62 columns):
#  #   Column                                    Non-Null Count  Dtype
# ---  ------                                    --------------  -----
#  0   Número de reserva                         17649 non-null  object
#  1   Número de reserva corto                   17649 non-null  object
#  2   Fecha de creación de la reserva (UTC)     17649 non-null  datetime64[ns]
#  3   Empresa usuaria                           17649 non-null  object
#  4   Estado civil                              10283 non-null  object
#  5   Matrícula                                 17649 non-null  object
#  6   Marca                                     17649 non-null  object
#  7   Modelo                                    17649 non-null  object
#  8   Categoría                                 17649 non-null  object
#  9   Cliente                                   17649 non-null  object
# ...

# %%
# Deleting few columns
DeleteList=['Zona horaria del sitio de inicio','Zona horaria del sitio final','Tipo de reserva','Número de factura',
            'Moneda','Cuota de retraso','Coste fijo de la penalización de retraso' , 'Penalización de retraso por hora','Comentario'
           ,'Comentario de NPS','Código del cupón','Grupo de vale']
df1=df1.drop(DeleteList, axis=1)

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17649 entries, 0 to 17648
# Data columns (total 50 columns):
#  #   Column                                 Non-Null Count  Dtype
# ---  ------                                 --------------  -----
#  0   Número de reserva                      17649 non-null  object
#  1   Número de reserva corto                17649 non-null  object
#  2   Fecha de creación de la reserva (UTC)  17649 non-null  datetime64[ns]
#  3   Empresa usuaria                        17649 non-null  object
#  4   Estado civil                           10283 non-null  object
#  5   Matrícula                              17649 non-null  object
#  6   Marca                                  17649 non-null  object
#  7   Modelo                                 17649 non-null  object
#  8   Categoría                              17649 non-null  object
#  9   Cliente                                17649 non-null  object
# ...

# %%
#rename the name of the variables
Df1 = df1.copy()                                     # Create copy of DataFrame
Df1.columns = ["Reservation number", "Short reservation number", "Reservation creation date", "User company","Civil status","Enrollment code",
               "Brand","Model","Category","Client","Inicial location","Final location","initial parking site","final parking site"," reservation status"
               ," Estimated start of reservation","Estimated end of reservation", "Actual reservation start","Actual reservation end","Delayed status","Delay duration","Travel time","Initial mile","Final mile"
               ,"Calculated trip mile","Initial fuel level","Final fuel level","Type of use","Paid reservation status","Duration time cost","cost of distance traveled"
               ,"Mileage included","Paid Kilometers","Price per km","Total without IVA","IVA amount","price included IVA"," Payment status",
               "Remaining amount to charge"," VIN number","Open carpool","NPS","Member ID",
               "Vehicle ID","pre-booked status","Replacement vehicle","Booking member type","Last update date","Last update done by","vehicle use"]                # Using columns attribute
